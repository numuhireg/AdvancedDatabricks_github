# %% [markdown]
# # Setting catalogs variables

# %%
dbutils.widgets.text("catalog_name","")
dbutils.widgets.text("schema_name", "")
dbutils.widgets.text("table_name", "")

# %%
catalog_name = dbutils.widgets.get("catalog_name")

# %%
workspace.default.products

# %%
df = spark.sql(f"select * from workspace.{table_name}")
display(df)

# %%
df = spark.sql(f"SHOW TABLES IN {catatog_name}.workspace.information_schema.columns")
display(df)

# %%
dbutils.widgets.text("schema", "main")
dbutils.widgets.text("table", "users")
