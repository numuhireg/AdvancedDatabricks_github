# %% [markdown]
# Install libray on the workspace

# %%
pip install Maven

# %%
# !python --version

# %%
# !pip list

# %%
pip install Maven

# %%
dbutils.library.restartPython()

# %%
pip install jar

# %%
# Step 1: In your Databricks workspace, go to your notebook's Libraries pane.
# Step 2: Click "Install New" > "Maven" and search for:
#         mysql:mysql-connector-java:8.0.33
# Step 3: Install the JAR.

# Step 4: Now run your code as below:
jdbc_url = "jdbc:mysql://localhost:3306/esc_training"
table = "employee"
properties = {
    "user": "root",
    "password": "root",
    "driver": "com.mysql.cj.jdbc.Driver"
}
df = spark.read.jdbc(
    jdbc_url,
    table,
    properties=properties
)
display(df)

# %%
# Install the MySQL JDBC driver using %pip
# %pip install mysql-connector-python

# Alternatively, if you need the official MySQL JDBC JAR, upload 'mysql-connector-java-x.x.xx.jar' to your cluster libraries via the Databricks UI.

# After installing, your code will work as expected:
jdbc_url = "jdbc:mysql://localhost:3306/esc_training"
table = "employee"
properties = {
    "user": "root",
    "password": "root",
    "driver": "com.mysql.cj.jdbc.Driver"
}
df = spark.read.jdbc(
    jdbc_url,
    table,
    properties=properties
)
display(df)
